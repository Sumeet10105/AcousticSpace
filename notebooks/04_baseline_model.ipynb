# %% [markdown]
# # 04 - Baseline Model
#
# This notebook trains a baseline CNN model for comparison.

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from src.models import cnn

# TODO: Train baseline model
