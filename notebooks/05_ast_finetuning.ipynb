# %% [markdown]
# # 05 - AST Fine-tuning
#
# This notebook fine-tunes Audio Spectrogram Transformer for audio spoofing detection.

# %%
import torch
import torch.nn as nn
from src.models import ast

# TODO: Fine-tune AST model
