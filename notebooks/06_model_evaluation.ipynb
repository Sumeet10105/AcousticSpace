# %% [markdown]
# # 06 - Model Evaluation
#
# This notebook evaluates trained models and computes metrics.

# %%
import torch
import numpy as np
from sklearn.metrics import confusion_matrix, roc_auc_score
from src.metrics import accuracy, eer, roc

# TODO: Evaluate model
